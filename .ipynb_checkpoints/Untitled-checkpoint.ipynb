# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('testapp.csv')

# %%
df.set_index('date')
# Out:
#             Unnamed: 0  Age_at_win  Prize_USD
# date
# 2010-02-28           0        23.0        136
# 2010-03-14           1        23.0        137
# 2011-01-23          10        24.0        267
# 2011-07-10         100        20.0      25000
# 2013-11-23        1000        17.0       2093
# 2016-01-10       10000         NaN        244
# 2015-04-05       10001         NaN        182
# 2016-03-26       10002         NaN         58
# 2012-07-15       10003         NaN        150
# 2015-05-03       10004         NaN         76
# 2016-04-03       10005         NaN         15
# 2012-05-06       10006         NaN        240
# 2011-04-15       10007         NaN         20
# 2011-08-16       10008         NaN         20
# 2012-07-22       10009         NaN        200
# 2014-05-14        1001        17.0        750
# 2012-06-03       10010         NaN         40
# 2013-03-29       10011         NaN        200
# 2013-07-28       10012         NaN        155
# ...

# %%
# Out:
#        Finals  PlayerId  PriorWins  SecondWins  TTtoDate  TournLength  \
# 0           0      1058          0           0         0            6
# 1           1      1058          1           0         1            6
# 10          9      1058          8           1        10            3
# 100         9      1000          6           3        15            3
# 1000        0      6406          0           0         0            3
# 10000      21      1062         13           8        33            9
# 10001      22      1062         13           9        34            6
# 10002      22      1062         13           9        35            2
# 10003      22      1062         13           9        36            6
# 10004      23      1062         13          10        37            5
# 10005      23      1062         13          10        38            6
# 10006      24      1062         14          10        39            6
# ...

# %%
df.to_json('extra_features.json')
